# %%
import pandas as pd
import seaborn as sns

# %%
df_results_all = pd.read_csv("times.csv")
df_results_all
sns.lineplot(data=df_results_all)
print("Priemer: ", df_results_all.mean(), "Pocet batchov: ", df_results_all.count())
# Out:
# Priemer:  times    27.607534
# dtype: float64 Pocet batchov:  times    322
# dtype: int64

# %%
df_results_all2 = pd.read_csv("times2.csv")
df_results_all2
sns.lineplot(data=df_results_all2)
print("Priemer: ", df_results_all2.mean(), "Pocet batchov: ", df_results_all2.count())
# Out:
# Priemer:  times    9.738099
# dtype: float64 Pocet batchov:  times    322
# dtype: int64
